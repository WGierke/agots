# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %%
# %autoreload

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from agots.multivariate_generators.multivariate_data_generator import MultivariateDataGenerator

# %%
np.random.seed(1337)

STREAM_LENGTH = 200
N = 4
K = 2

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
# Out:
#           x0        x1        x2        x3
# x0  1.000000  0.985941 -0.144821 -0.186724
# x1  0.985941  1.000000 -0.129324 -0.187107
# x2 -0.144821 -0.129324  1.000000  0.197286
# x3 -0.186724 -0.187107  0.197286  1.000000

# %%
df
# Out:
#             x0        x1        x2        x3
# 0     3.000000 -3.000000  2.000000  1.000000
# 1     3.060530 -2.887943  2.419412  0.908175
# 2     2.773117 -3.003151  2.359755  0.756587
# 3     2.816198 -2.953174  2.774531  0.618809
# 4     2.350169 -2.929736  2.893389  1.019772
# 5     2.085558 -3.566645  3.299516  0.859867
# 6     2.177671 -3.340701  3.712991  0.423561
# 7     2.012698 -3.302543  3.611960  0.424597
# 8     1.783180 -3.384022  3.363775  0.011063
# 9     1.590633 -3.465373  3.730589 -0.406819
# 10    1.893002 -3.486088  3.773050  0.055843
# 11    1.488150 -3.474417  4.014207  0.013911
# 12    1.351290 -3.912176  3.804653  0.454455
# 13    1.592446 -3.730252  3.551222  0.693068
# 14    1.252394 -3.458582  3.352049  0.833815
# 15    1.615042 -3.666618  2.875478  0.793399
# 16    1.904937 -3.509938  3.097578  0.371861
# 17    1.410280 -3.774180  3.353890  0.585673
# 18    1.373855 -4.040941  3.002045  0.387076
# 19    1.254923 -3.688319  3.142167  0.661533
# 20    1.275424 -3.755768  2.992232  0.468495
# 21    1.145376 -3.758103  2.830961  0.462192
# 22    1.121012 -4.098771  2.378525  0.592780
# 23    1.484584 -4.130221  2.425763  0.263948
# 24    1.389605 -3.927507  2.558669  0.391410
# 25    1.330106 -3.643611  2.808818  0.003234
# 26    0.970960 -3.883088  2.898174 -0.142106
# 27    1.291141 -4.174954  3.334946 -0.240766
# 28    1.688795 -3.788701  3.226214 -0.502973
# 29    2.117202 -3.886541  3.440229 -0.019758
# ..         ...       ...       ...       ...
# 170   8.893828 -0.397635  0.611777 -1.053146
# 171   8.664630  0.170366  0.852345 -0.571571
# 172   9.126901  0.037320  0.883148 -0.075540
# 173   9.070452  0.118585  1.294560  0.027764
# 174   8.710409  0.283309  1.650591 -0.286059
# 175   8.721622  0.098504  1.915065 -0.252924
# 176   8.927362  0.049789  2.106074  0.236873
# 177   8.746750 -0.035581  2.012135  0.095387
# 178   8.517075  0.029201  1.749971 -0.229970
# 179   8.925363 -0.093511  1.598497  0.129212
# 180   9.025887 -0.198525  1.321479  0.440794
# 181   8.998970  0.066650  1.055043 -0.058375
# 182   9.187786 -0.201576  1.056138 -0.172806
# 183   9.180293 -0.041696  0.697511  0.108731
# 184   9.524613 -0.088232  1.119343  0.066564
# 185   9.633443  0.167090  1.336723  0.255515
# 186   9.522356  0.293437  1.367033  0.612731
# 187   9.960627  0.159368  1.596895  0.735369
# 188   9.735163  0.510068  1.288135  0.999685
# 189   9.662709  0.553475  1.741386  1.132604
# 190   9.904374  0.184893  1.485044  0.670088
# 191  10.334505  0.230987  1.972141  0.412289
# 192  10.133042  0.871281  1.913733  0.614529
# 193  10.258895  0.486600  2.151388  0.213664
# 194   9.792009  0.800073  1.742501  0.509913
# 195   9.909111  0.612172  1.757602  0.185826
# 196  10.124215  0.609309  1.718569 -0.300031
# 197  10.584127  0.343486  1.602878 -0.286739
# 198  10.242992  0.743488  1.707858 -0.258555
# 199  10.371311  0.499875  1.298326 -0.278375
#
# [200 rows x 4 columns]

# %%
df = dg.add_outliers({'extreme': [{'n': 0, 'timestamps': [(0,), (190,)]}],
                      'shift':   [{'n': 1, 'timestamps': [(0,190)]}],
                      'trend':   [{'n': 2, 'timestamps': [(0, 150)]}],
                      'variance':[{'n': 3, 'timestamps': [(0, 100)]}]})

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()
df
# Out:
# Python 3.6.5 (default, Apr 17 2018, 21:58:01)
# Type 'copyright', 'credits' or 'license' for more information
# IPython 6.3.1 -- An enhanced Interactive Python. Type '?' for help.
#
# In [1]: df
# Out[1]:
# 0     -3.000000
# 1     -2.887943
# 2     -3.003151
# 3     -2.953174
# 4     -2.929736
# 5     -3.566645
# 6     -3.340701
# 7     -3.302543
# 8     -3.384022
# 9     -3.465373
# 10    -3.486088
# 11    -3.474417
# 12    -3.912176
# 13    -3.730252
# 14    -3.458582
# 15    -3.666618
# 16    -3.509938
# 17    -3.774180
# 18    -4.040941
# 19    -3.688319
# 20    -3.755768
# 21    -3.758103
# 22    -4.098771
# 23    -4.130221
# 24    -3.927507
# 25    -3.643611
# 26    -3.883088
# 27    -4.174954
# 28    -3.788701
# 29    -3.886541
#          ...
# 170   -0.397635
# 171    0.170366
# 172    0.037320
# 173    0.118585
# 174    0.283309
# 175    0.098504
# 176    0.049789
# 177   -0.035581
# 178    0.029201
# 179   -0.093511
# 180   -0.198525
# 181    0.066650
# 182   -0.201576
# 183   -0.041696
# 184   -0.088232
# 185    0.167090
# 186    0.293437
# 187    0.159368
# 188    0.510068
# 189    0.553475
# 190    0.184893
# 191    0.230987
# 192    0.871281
# 193    0.486600
# 194    0.800073
# 195    0.612172
# 196    0.609309
# 197    0.343486
# 198    0.743488
# 199    0.499875
# Name: x1, Length: 200, dtype: float64
#
# In [2]: df.__class__
# Out[2]: pandas.core.series.Series
